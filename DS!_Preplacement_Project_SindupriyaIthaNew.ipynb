# %%
#Importing required Libraries

import matplotlib.pyplot as plt       #To visualize
from tabulate import tabulate         #To print the table
import matplotlib as mat              #To visualize 
import seaborn as sns                 #To visualize
import pandas as pd                   #For data reading
import numpy as np                    #For numbers

# %%
df = pd.read_csv("shopping_trends.csv")  #Reading data file

# %%
df  #calling data frame
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
#Univariate Analysis

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.tail()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  \
# 3895                     28    Virginia    L  Turquoise  Summer
# 3896                     49        Iowa    L      White  Spring
# 3897                     33  New Jersey    L      Green  Spring
# 3898                     77   Minnesota    S      Brown  Summer
# 3899                     81  California    M      Beige  Spring
#
#       Review Rating Subscription Status Payment Method   Shipping Type  \
# 3895            4.2                  No           Cash  2-Day Shipping
# 3896            4.5                  No         PayPal    Store Pickup
# ...

# %%
print(df.shape)
# Out:
# (3900, 19)

# %%
print(df.columns)
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
# Checking if there are any duplicate values and removing them.
duplicates = df[df.duplicated(keep=False)]

if not duplicates.empty:
    df.drop_duplicates(inplace = True)
    print("Removed all the duplicate values from the data")
else:
    print("No duplicate rows found")
# Out:
# No duplicate rows found

# %% [markdown]
# # Level 1 Analysis Stage

# %%
# Seprating out the categorical and Numerical columns
def seprate_data_types(df):
    categorical = []
    continuous = []
    for column in df.columns:                #looping on the number of columns
        if df[column].nunique() < 100:       #nunique returns unique values in the column
                                             #here 100 is the hyperparamter and can be changed
            categorical.append(column)
        else:
            continuous.append(column)
            
    return categorical, continuous 


categorical, continuous = seprate_data_types(df)         # Calling the function

#tabulate is a package used to print the list, dict or any data sets in a proper format; in table format
from tabulate import tabulate
table = [categorical, continuous]
print(tabulate({"Categorical":categorical,
                "continuous": continuous}, headers = ["categorical", "continuous"]))
# Out:
# categorical               continuous
# ------------------------  ------------
# Age                       Customer ID
# Gender
# Item Purchased
# Category
# Purchase Amount (USD)
# Location
# Size
# Color
# Season
# Review Rating
# Subscription Status
# Payment Method
# Shipping Type
# Discount Applied
# Promo Code Used
# Previous Purchases
# Preferred Payment Method
# Frequency of Purchases

# %% [markdown]
# # Bivarient Analysis

# %%
def info_of_cat(col): 
    print(f"Unique values in {col} are: {df[col].unique()}") # unique: returns the unique values in the col
    print(f"Mode of {col} is {df[col].mode()[0]}")  # mode: returns the mode of the column
    print(f"Number of missing values in {col} is {df[col].isnull().sum()}") # isnull().sum() counts the number of null in dataframe

# %%
info_of_cat("Age")
# Out:
# Unique values in Age are: [55 19 50 21 45 46 63 27 26 57 53 30 61 65 64 25 52 66 31 56 18 38 54 33
#  36 35 29 70 69 67 20 39 42 68 49 59 47 40 41 48 22 24 44 37 58 32 62 51
#  28 43 34 23 60]
# Mode of Age is 69
# Number of missing values in Age is 0

# %%
info_of_cat("Gender")
# Out:
# Unique values in Gender are: ['Male' 'Female']
# Mode of Gender is Male
# Number of missing values in Gender is 0

# %%
info_of_cat("Item Purchased")
# Out:
# Unique values in Item Purchased are: ['Blouse' 'Sweater' 'Jeans' 'Sandals' 'Sneakers' 'Shirt' 'Shorts' 'Coat'
#  'Handbag' 'Shoes' 'Dress' 'Skirt' 'Sunglasses' 'Pants' 'Jacket' 'Hoodie'
#  'Jewelry' 'T-shirt' 'Scarf' 'Hat' 'Socks' 'Backpack' 'Belt' 'Boots'
#  'Gloves']
# Mode of Item Purchased is Blouse
# Number of missing values in Item Purchased is 0

# %%
info_of_cat("Category")
# Out:
# Unique values in Category are: ['Clothing' 'Footwear' 'Outerwear' 'Accessories']
# Mode of Category is Clothing
# Number of missing values in Category is 0

# %%
info_of_cat("Purchase Amount (USD)")
# Out:
# Unique values in Purchase Amount (USD) are: [ 53  64  73  90  49  20  85  34  97  31  68  72  51  81  36  38  48  62
#   37  88  22  25  56  94  79  67  91  33  69  45  60  76  39 100  21  43
#   54  55  30  28  59  24  83  46  70  29  26  58  96  40  32  95  41  47
#   99  87  92  98  89  35  75  65  86  84  77  27  23  74  80  42  61  82
#   78  93  50  57  66  44  52  71  63]
# Mode of Purchase Amount (USD) is 32
# Number of missing values in Purchase Amount (USD) is 0

# %%
info_of_cat("Location")
# Out:
# Unique values in Location are: ['Kentucky' 'Maine' 'Massachusetts' 'Rhode Island' 'Oregon' 'Wyoming'
#  'Montana' 'Louisiana' 'West Virginia' 'Missouri' 'Arkansas' 'Hawaii'
#  'Delaware' 'New Hampshire' 'New York' 'Alabama' 'Mississippi'
#  'North Carolina' 'California' 'Oklahoma' 'Florida' 'Texas' 'Nevada'
#  'Kansas' 'Colorado' 'North Dakota' 'Illinois' 'Indiana' 'Arizona'
#  'Alaska' 'Tennessee' 'Ohio' 'New Jersey' 'Maryland' 'Vermont'
#  'New Mexico' 'South Carolina' 'Idaho' 'Pennsylvania' 'Connecticut' 'Utah'
#  'Virginia' 'Georgia' 'Nebraska' 'Iowa' 'South Dakota' 'Minnesota'
#  'Washington' 'Wisconsin' 'Michigan']
# Mode of Location is Montana
# Number of missing values in Location is 0

# %%
info_of_cat("Size")
# Out:
# Unique values in Size are: ['L' 'S' 'M' 'XL']
# Mode of Size is M
# Number of missing values in Size is 0

# %%
info_of_cat("Color")
# Out:
# Unique values in Color are: ['Gray' 'Maroon' 'Turquoise' 'White' 'Charcoal' 'Silver' 'Pink' 'Purple'
#  'Olive' 'Gold' 'Violet' 'Teal' 'Lavender' 'Black' 'Green' 'Peach' 'Red'
#  'Cyan' 'Brown' 'Beige' 'Orange' 'Indigo' 'Yellow' 'Magenta' 'Blue']
# Mode of Color is Olive
# Number of missing values in Color is 0

# %%
info_of_cat("Season")
# Out:
# Unique values in Season are: ['Winter' 'Spring' 'Summer' 'Fall']
# Mode of Season is Spring
# Number of missing values in Season is 0

# %%
info_of_cat("Review Rating")
# Out:
# Unique values in Review Rating are: [3.1 3.5 2.7 2.9 3.2 2.6 4.8 4.1 4.9 4.5 4.7 2.8 4.6 3.3 4.4 3.6 5.  4.
#  3.7 4.2 3.9 3.  3.8 3.4 4.3 2.5]
# Mode of Review Rating is 3.4
# Number of missing values in Review Rating is 0

# %%
info_of_cat("Subscription Status")
# Out:
# Unique values in Subscription Status are: ['Yes' 'No']
# Mode of Subscription Status is No
# Number of missing values in Subscription Status is 0

# %%
info_of_cat("Payment Method")
# Out:
# Unique values in Payment Method are: ['Credit Card' 'Bank Transfer' 'Cash' 'PayPal' 'Venmo' 'Debit Card']
# Mode of Payment Method is Credit Card
# Number of missing values in Payment Method is 0

# %%
info_of_cat("Shipping Type")
# Out:
# Unique values in Shipping Type are: ['Express' 'Free Shipping' 'Next Day Air' 'Standard' '2-Day Shipping'
#  'Store Pickup']
# Mode of Shipping Type is Free Shipping
# Number of missing values in Shipping Type is 0

# %%
info_of_cat("Discount Applied")
# Out:
# Unique values in Discount Applied are: ['Yes' 'No']
# Mode of Discount Applied is No
# Number of missing values in Discount Applied is 0

# %%
info_of_cat("Promo Code Used")
# Out:
# Unique values in Promo Code Used are: ['Yes' 'No']
# Mode of Promo Code Used is No
# Number of missing values in Promo Code Used is 0

# %%
info_of_cat("Previous Purchases")
# Out:
# Unique values in Previous Purchases are: [14  2 23 49 31 19  8  4 26 10 37 34 44 36 17 46 50 22 32 40 16 13  7 41
#  45 38 48 18 15 25 39 35 29 21 43  3  5 24 42 47 28 20 33  1  9 12 27 11
#  30  6]
# Mode of Previous Purchases is 31
# Number of missing values in Previous Purchases is 0

# %%
info_of_cat("Preferred Payment Method")
# Out:
# Unique values in Preferred Payment Method are: ['Venmo' 'Cash' 'Credit Card' 'PayPal' 'Bank Transfer' 'Debit Card']
# Mode of Preferred Payment Method is PayPal
# Number of missing values in Preferred Payment Method is 0

# %%
info_of_cat("Frequency of Purchases")
# Out:
# Unique values in Frequency of Purchases are: ['Fortnightly' 'Weekly' 'Annually' 'Quarterly' 'Bi-Weekly' 'Monthly'
#  'Every 3 Months']
# Mode of Frequency of Purchases is Every 3 Months
# Number of missing values in Frequency of Purchases is 0

# %%
info_of_cat("Customer ID")
# Out:
# Unique values in Customer ID are: [   1    2    3 ... 3898 3899 3900]
# Mode of Customer ID is 1
# Number of missing values in Customer ID is 0

# %% [markdown]
# # Numerical Analysis And Removing Outliers

# %%
def info_of_numerical(col):
    print(f"The mean of the {col} is {df[col].mean()}")
    print(f"The median of the {col} is {df[col].median()}")
    print(f"The mode of the {col} is {df[col].mode()[0]}")
    print(f"The standard deviation of the {col} is {df[col].std()}")
    print(f"Number of missing values in the {col} is {df[col].isnull().sum()}")

# %%
info_of_numerical("Customer ID")
# Out:
# The mean of the Customer ID is 1950.5
# The median of the Customer ID is 1950.5
# The mode of the Customer ID is 1
# The standard deviation of the Customer ID is 1125.9773532358456
# Number of missing values in the Customer ID is 0

# %%
info_of_numerical("Purchase Amount (USD)")
# Out:
# The mean of the Purchase Amount (USD) is 59.76435897435898
# The median of the Purchase Amount (USD) is 60.0
# The mode of the Purchase Amount (USD) is 32
# The standard deviation of the Purchase Amount (USD) is 23.685392250875307
# Number of missing values in the Purchase Amount (USD) is 0

# %%
info_of_numerical("Age")
# Out:
# The mean of the Age is 44.06846153846154
# The median of the Age is 44.0
# The mode of the Age is 69
# The standard deviation of the Age is 15.20758912716238
# Number of missing values in the Age is 0

# %%
info_of_numerical("Review Rating")
# Out:
# The mean of the Review Rating is 3.7499487179487176
# The median of the Review Rating is 3.7
# The mode of the Review Rating is 3.4
# The standard deviation of the Review Rating is 0.7162228139312449
# Number of missing values in the Review Rating is 0

# %%
info_of_numerical("Previous Purchases")
# Out:
# The mean of the Previous Purchases is 25.35153846153846
# The median of the Previous Purchases is 25.0
# The mode of the Previous Purchases is 31
# The standard deviation of the Previous Purchases is 14.447125170462431
# Number of missing values in the Previous Purchases is 0

# %% [markdown]
# # Data Cleaning is done

# %% [markdown]
# # level 2

# %%
print(tabulate({"Categorical":categorical,
                "continuous": continuous}, headers = ["categorical", "continuous"]))
# Out:
# categorical               continuous
# ------------------------  ------------
# Age                       Customer ID
# Gender
# Item Purchased
# Category
# Purchase Amount (USD)
# Location
# Size
# Color
# Season
# Review Rating
# Subscription Status
# Payment Method
# Shipping Type
# Discount Applied
# Promo Code Used
# Previous Purchases
# Preferred Payment Method
# Frequency of Purchases

# %%
#Visualize the distribution of a numerical variable using a histogram

# %% [markdown]
# # Interpretation: Customer Age for shopping is widely distributed between age group 20 to 70

# %%
# Plot a histogram for a specific variable (e.g., "Gender")
plt.figure(figsize=(8, 6))
sns.histplot(df["Gender"], kde=True, color="orange")
plt.xlabel("Gender")
plt.ylabel("Frequency")
plt.title("Gender of Customers")
plt.show()

# %% [markdown]
# # Interpretation:Male customers shop more than female customers

# %%
# Plot a histogram for a specific variable (e.g., "Shipping Type")
plt.figure(figsize=(8, 6))
sns.histplot(df["Shipping Type"], kde=True, color="Red")
plt.xlabel("Shipping Type")
plt.ylabel("Frequency")
plt.title("Shipping Type")
plt.show()

# %% [markdown]
# # Interpretation: Free Shipping is preferred shipping method used by customers

# %%
# Get the count of each category in a specific column (e.g., "Category")
category_counts = df["Category"].value_counts()
print(category_counts)
# Out:
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: Category, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a count plot for the "Category" variable
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x="Category", palette="pastel")
plt.xlabel("Category")
plt.ylabel("Count")
plt.title("Count Plot of Category")
plt.xticks(rotation=45)  # Rotate the x-axis labels for better readability
plt.show()

# %% [markdown]
# # Interpetation: In Category, Clothing counts for the highest available items

# %%
# Create a box plot for a specific variable (e.g., "Age")
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x="Age", color="lightcoral")
plt.xlabel("Age")
plt.title("Box Plot of age")
plt.show()

# %% [markdown]
# # Bivarient Alaysis

# %%
#Relationship between gender and category
import pandas as pd
from scipy.stats import chi2_contingency

# Create a contingency table
contingency_table = pd.crosstab(df['Gender'], df['Category'])

# Perform the chi-squared test for independence
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Check the p-value to determine if there is a significant relationship
if p < 0.05:
    print("There is a significant relationship between Gender and Category.")
else:
    print("There is no significant relationship between Gender and Category.")

    #Visualization: grouped bar chart


import seaborn as sns
import matplotlib.pyplot as plt

# Create a grouped bar chart
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x="Gender", hue="Category", palette="Set3")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Bivariate Analysis: Gender and Category")
plt.legend(title="Category", loc="upper right")
plt.show()
# Out:
# There is no significant relationship between Gender and Category.

# %%
#Relationship between  Item Purchased  and Season
import pandas as pd
from scipy.stats import chi2_contingency

# Create a contingency table
contingency_table = pd.crosstab(df['Season'], df['Item Purchased'])

# Perform the chi-squared test for independence
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Check the p-value to determine if there is a significant relationship
if p < 0.05:
    print("There is a significant relationship between Season and Item Purchased.")
else:
    print("There is no significant relationship between Season and Item Purchased.")

    #Visualization: grouped bar chart


import seaborn as sns
import matplotlib.pyplot as plt

# Create a grouped bar chart
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x="Season", hue="Item Purchased", palette="Set3")
plt.xlabel("Season")
plt.ylabel("Count")
plt.title("Bivariate Analysis: Season and Item Purchased")
plt.legend(title="Item Purchased", loc="upper right")
plt.show()
# Out:
# There is no significant relationship between Season and Item Purchased.

# %%
#Relationship between  Item Purchased  and Gender
import pandas as pd
from scipy.stats import chi2_contingency

# Create a contingency table
contingency_table = pd.crosstab(df['Gender'], df['Item Purchased'])

# Perform the chi-squared test for independence
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Check the p-value to determine if there is a significant relationship
if p < 0.05:
    print("There is a significant relationship between Gender and Item Purchased.")
else:
    print("There is no significant relationship between Gender and Item Purchased.")

    #Visualization: grouped bar chart


import seaborn as sns
import matplotlib.pyplot as plt

# Create a grouped bar chart
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x="Gender", hue="Item Purchased", palette="Set3")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Bivariate Analysis: Gender and Item Purchased")
plt.legend(title="Item Purchased", loc="upper right")
plt.show()
# Out:
# There is no significant relationship between Gender and Item Purchased.

# %%
#Relationship between  Item Purchased  and Review Rating
import pandas as pd
from scipy.stats import chi2_contingency

# Create a contingency table
contingency_table = pd.crosstab(df['Review Rating'], df['Item Purchased'])

# Perform the chi-squared test for independence
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Check the p-value to determine if there is a significant relationship
if p < 0.05:
    print("There is a significant relationship between Review Rating and Item Purchased.")
else:
    print("There is no significant relationship between Review Rating and Item Purchased.")

    #Visualization: grouped bar chart


import seaborn as sns
import matplotlib.pyplot as plt

# Create a grouped bar chart
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x="Review Rating", hue="Item Purchased", palette="Set3")
plt.xlabel("Review Rating")
plt.ylabel("Count")
plt.title("Bivariate Analysis: Review Rating and Item Purchased")
plt.legend(title="Item Purchased", loc="upper right")
plt.show()
# Out:
# There is no significant relationship between Review Rating and Item Purchased.

# %% [markdown]
# # Multivarient Analysis

# %%
# Calculate the correlation matrix
correlation_matrix = df.corr()

print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                        Customer ID       Age  Purchase Amount (USD)  \
# Customer ID               1.000000 -0.004079               0.011048
# Age                      -0.004079  1.000000              -0.010424
# Purchase Amount (USD)     0.011048 -0.010424               1.000000
# Review Rating             0.001343 -0.021949               0.030776
# Previous Purchases       -0.039159  0.040445               0.008063
#
#                        Review Rating  Previous Purchases
# Customer ID                 0.001343           -0.039159
# Age                        -0.021949            0.040445
# Purchase Amount (USD)       0.030776            0.008063
# Review Rating               1.000000            0.004229
# Previous Purchases          0.004229            1.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Create scatterplot matrix
sns.set(style="ticks")
sns.pairplot(df, kind="scatter")
plt.show()

# %% [markdown]
# # Interpretation:
# #The correlation between "Age" and "Purchase Amount (USD)" is positive.I implies older customers tend to spend more
#
# #The correlation between "Age" and "Review Rating" is positive. So it implies that older customers tend to give higher ratings on average.
#
# #The correlation between "Purchase Amount (USD)" and "Review Rating" is positive.Means, customers who spend more on their purchases tend to give higher ratings,
# #indicating a positive association between spending and satisfaction.

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector as sql
db = sql.connect(host='localhost', user='root',password='Sindu@1989',database='Shopping_Trends')
mycursor = db.cursor()
from sqlalchemy import create_engine

#Define the database connection string fro MYSQL
db_connection = create_engine('mysql+mysqlconnector://root:Sindu@1989@localhost/Shopping_Trends')

df.to_sql('Shopping_Trends', con =db_connection, if_exists = 'replace', index = False)

db.commit()
